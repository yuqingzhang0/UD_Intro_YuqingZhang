# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.webdriver.chrome.options import Options
import time
from bs4 import BeautifulSoup
import os
from time import sleep

chromedriver = r"C:\Users\zyq\ladybug_tools\python\Scripts\chromedriver.exe"

url = "https://www.eventbrite.co.uk/d/united-kingdom--london/soul-music/"
title_list = []
result_list = []
address_list = []

driver = webdriver.Chrome()
driver.get(url)
sleep(5)

i = 1
for i in range (50):
    #ADD ADDRESS
    title = driver.find_element('xpath','//*[@id="root"]/div/div[2]/div/div/div/div[1]/div/main/div/div/section[1]/div/section/div/div/section/ul/li[1]/div/div[2]/section/div/section[2]/div/p[2]').text
    print (title)
    sleep(5)
    title_list.append(title)
    title = driver.find_element('xpath','//*[@id="root"]/div/div[2]/div/div/div/div[1]/div/main/div/div/section[1]/div/section/div/div/section/ul/li[2]/div/div[2]/section/div/section[2]/div/p[2]').text
    print (title)
    sleep(5)
    title_list.append(title)
    title = driver.find_element('xpath','//*[@id="root"]/div/div[2]/div/div/div/div[1]/div/main/div/div/section[1]/div/section/div/div/section/ul/li[3]/div/div[2]/section/div/section[2]/div/p[2]').text
    print (title)
    sleep(5)
    title_list.append(title)
    title = driver.find_element('xpath','//*[@id="root"]/div/div[2]/div/div/div/div[1]/div/main/div/div/section[1]/div/section/div/div/section/ul/li[4]/div/div[2]/section/div/section[2]/div/p[2]').text
    print (title)
    sleep(5)
    title_list.append(title)
    title = driver.find_element('xpath','//*[@id="root"]/div/div[2]/div/div/div/div[1]/div/main/div/div/section[1]/div/section/div/div/section/ul/li[5]/div/div[2]/section/div/section[2]/div/p[2]').text
    print (title)
    sleep(5)
    title_list.append(title)
    title = driver.find_element('xpath','//*[@id="root"]/div/div[2]/div/div/div/div[1]/div/main/div/div/section[1]/div/section/div/div/section/ul/li[6]/div/div[2]/section/div/section[2]/div/p[2]').text
    print (title)
    sleep(5)
    title_list.append(title)
    title = driver.find_element('xpath','//*[@id="root"]/div/div[2]/div/div/div/div[1]/div/main/div/div/section[1]/div/section/div/div/section/ul/li[7]/div/div[2]/section/div/section[2]/div/p[2]').text
    print (title)
    sleep(5)
    title_list.append(title)
    title = driver.find_element('xpath','//*[@id="root"]/div/div[2]/div/div/div/div[1]/div/main/div/div/section[1]/div/section/div/div/section/ul/li[8]/div/div[2]/section/div/section[2]/div/p[2]').text
    print (title)
    sleep(5)
    title_list.append(title)
    title = driver.find_element('xpath','//*[@id="root"]/div/div[2]/div/div/div/div[1]/div/main/div/div/section[1]/div/section/div/div/section/ul/li[9]/div/div[2]/section/div/section[2]/div/p[2]').text
    print (title)
    sleep(5)
    title_list.append(title)
    title = driver.find_element('xpath','//*[@id="root"]/div/div[2]/div/div/div/div[1]/div/main/div/div/section[1]/div/section/div/div/section/ul/li[10]/div/div[2]/section/div/section[2]/div/p[2]').text
    print (title)
    sleep(5)
    title_list.append(title)
    title = driver.find_element('xpath','//*[@id="root"]/div/div[2]/div/div/div/div[1]/div/main/div/div/section[1]/div/section/div/div/section/ul/li[11]/div/div[2]/section/div/section[2]/div/p[2]').text
    print (title)
    sleep(5)
    title_list.append(title)
    title = driver.find_element('xpath','//*[@id="root"]/div/div[2]/div/div/div/div[1]/div/main/div/div/section[1]/div/section/div/div/section/ul/li[12]/div/div[2]/section/div/section[2]/div/p[2]').text
    print (title)
    sleep(5)
    title_list.append(title)
    title = driver.find_element('xpath','//*[@id="root"]/div/div[2]/div/div/div/div[1]/div/main/div/div/section[1]/div/section/div/div/section/ul/li[13]/div/div[2]/section/div/section[2]/div/p[2]').text
    print (title)
    sleep(5)
    title_list.append(title)
    title = driver.find_element('xpath','//*[@id="root"]/div/div[2]/div/div/div/div[1]/div/main/div/div/section[1]/div/section/div/div/section/ul/li[14]/div/div[2]/section/div/section[2]/div/p[2]').text
    print (title)
    sleep(5)
    title_list.append(title)
    title = driver.find_element('xpath','//*[@id="root"]/div/div[2]/div/div/div/div[1]/div/main/div/div/section[1]/div/section/div/div/section/ul/li[15]/div/div[2]/section/div/section[2]/div/p[2]').text
    print (title)
    sleep(5)
    title_list.append(title)
    title = driver.find_element('xpath','//*[@id="root"]/div/div[2]/div/div/div/div[1]/div/main/div/div/section[1]/div/section/div/div/section/ul/li[16]/div/div[2]/section/div/section[2]/div/p[2]').text
    print (title)
    sleep(5)
    title_list.append(title)
    title = driver.find_element('xpath','//*[@id="root"]/div/div[2]/div/div/div/div[1]/div/main/div/div/section[1]/div/section/div/div/section/ul/li[17]/div/div[2]/section/div/section[2]/div/p[2]').text
    print (title)
    sleep(5)
    title_list.append(title)
    title = driver.find_element('xpath','//*[@id="root"]/div/div[2]/div/div/div/div[1]/div/main/div/div/section[1]/div/section/div/div/section/ul/li[18]/div/div[2]/section/div/section[2]/div/p[2]').text
    print (title)
    sleep(5)
    title_list.append(title)
    title = driver.find_element('xpath','//*[@id="root"]/div/div[2]/div/div/div/div[1]/div/main/div/div/section[1]/div/section/div/div/section/ul/li[19]/div/div[2]/section/div/section[2]/div/p[2]').text
    print (title)
    sleep(5)
    title_list.append(title)
    title = driver.find_element('xpath','//*[@id="root"]/div/div[2]/div/div/div/div[1]/div/main/div/div/section[1]/div/section/div/div/section/ul/li[20]/div/div[2]/section/div/section[2]/div/p[2]').text
    print (title)
    sleep(5)
    title_list.append(title)
    print(title_list)
    
    sleep(5)
    driver.find_element("xpath","//*[@id='root']/div/div[2]/div/div/div/div[1]/div/main/div/div/section[1]/div/section/div/div/footer/div/div/ul/li[3]/button").click()
    i += 1
    sleep(10)

import csv

data = zip(title_list)

with open('eventbrite.csv','w',encoding = 'utf-8') as csvfile:
    writer = csv.writer(csvfile)
    for row in data:
        writer.writerow(row)
# Out:
# 19FiftySeven Restaurant
# The Camden Club
# KOKO
# The Front Room
# Klm centre
# Prive Lounge Bar
# Mosaic Kitchen
# Our Lady of Lourdes Church
# 100 Club
# Temple of Art and Music (TAM) @ Mercato Metropolitano
# Social Convention - a home for queer culture - LGBTQ+ bar & event space
# The Wheatsheaf
# The Great North Wood
# The Brickstone
# Oliver's Bar & Restaurant
# The Hackney Social
# KOKO
# Poplar Union
# James Hockey & Foyer Galleries
# Fox & Firkin
# ['19FiftySeven Restaurant', 'The Camden Club', 'KOKO', 'The Front Room', 'Klm centre', 'Prive Lounge Bar', 'Mosaic Kitchen', 'Our Lady of Lourdes Church', '100 Club', 'Temple of Art and Music (TAM) @ Mercato Metropolitano', 'Social Convention - a home for queer culture - LGBTQ+ bar & event space', 'The Wheatsheaf', 'The Great North Wood', 'The Brickstone', "Oliver's Bar & Restaurant", 'The Hackney Social', 'KOKO', 'Poplar Union', 'James Hockey & Foyer Galleries', 'Fox & Firkin']
# Doña
# Holdspace Wynford Hall
# Barbican Centre
# ...
